# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import urllib.request
import json

with urllib.request.urlopen("https://api.apify.com/v2/key-value-stores/ad2dUV2Kkxba6XhO1/records/LATEST?disableRedirect=true") as url:
    data = json.loads(url.read().decode())

# %%
df = pd.DataFrame(data['data']['daily'])

# %%
df
# Out:
#               2020-02-27           2020-02-28          2020-02-29  \
# c       {'n': 0, 't': 0}     {'n': 0, 't': 0}    {'n': 0, 't': 0}
# t   {'n': 170, 't': 170}  {'n': 23, 't': 193}  {'n': 7, 't': 200}
# q                    NaN                  NaN                 NaN
# r0                   NaN                  NaN                 NaN
# h                    NaN                  NaN                 NaN
# d                    NaN                  NaN                 NaN
#
#              2020-03-01           2020-03-02           2020-03-03  \
# c      {'n': 3, 't': 3}     {'n': 0, 't': 3}     {'n': 2, 't': 5}
# t   {'n': 11, 't': 211}  {'n': 51, 't': 262}  {'n': 78, 't': 340}
# q             {'n': 35}           {'n': 128}           {'n': 165}
# r0                  NaN                  NaN                  NaN
# h                   NaN                  NaN                  NaN
# d                   NaN                  NaN                  NaN
#
# ...

# %%
daily = pd.DataFrame(df.T['c'])

# %%
df['c'][1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/Projects/jupyter/.venv/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'c'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-6da4131aa37b> in <module>
# ----> 1 df['c'][1]
#
# ...
